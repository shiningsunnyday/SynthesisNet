# %%
from pathlib import Path
from scipy import sparse

paths = list(Path('/home/msun415/SynTreeNet/data/gnn_featurized_rxn_target_down_bb_postorder_max_depth=3_split_train/').rglob("0_*_node_mask*"))

# %%
for path in paths:
    data = sparse.load_npz(path)
    print(data.shape)
# Out:
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# (16, 9)
# ...

# %%
import pickle
data = pickle.load(open('/home/msun415/SynTreeNet/results/viz/skeletons.pkl', 'rb'))
sts = list(data)
# Out:
# 11:56:58 rdkit INFO: Enabling RDKit 2022.09.5 jupyter extensions

# %%
from synnet.utils.data_utils import Skeleton

indices = {}
for i in range(len(sts)):
    sk = Skeleton(sts[i], i)
    if sk.rxns.sum() <= 6:
        indices[sk.rxns.sum()] = indices.get(sk.rxns.sum(), []) + [i]

# %%
indices
# Out:
# {3: [0,
#   5,
#   13,
#   14,
#   16,
#   17,
#   18,
#   20,
#   23,
#   25,
#   28,
#   31,
#   36,
#   39,
#   57,
#   76,
#   84,
#   103,
#   118,
#   119,
#   155,
#   217],
#  1: [1, 2],
#  2: [3, 6, 8, 9, 10, 15],
#  4: [4,
#   7,
#   11,
#   19,
#   21,
#   22,
#   24,
#   26,
#   29,
#   32,
#   34,
#   35,
#   38,
#   43,
#   44,
#   46,
#   51,
#   53,
#   59,
#   65,
#   70,
#   74,
#   78,
#   83,
#   85,
#   93,
#   97,
#   107,
#   120,
#   128,
#   133,
#   135,
#   140,
#   142,
#   150,
#   151,
#   156,
#   160,
#   163,
#   166,
#   169,
#   173,
#   175,
#   178,
#   186,
#   199,
#   200,
#   204,
#   224,
#   225,
#   233,
#   236,
#   250,
#   258,
#   259,
#   268,
#   271,
#   323,
#   335,
#   347,
#   348,
#   353,
#   370,
#   390,
#   393,
#   474,
#   507,
#   526,
#   557,
#   598,
#   609,
#   628,
#   681,
#   717,
#   737,
#   765,
#   770,
#   782,
#   784,
#   930,
#   989,
#   1040,
#   1066],
#  6: [12,
#   48,
#   49,
#   54,
#   72,
#   73,
# ...

# %%
from pathlib import Path
import shutil
import os
for max_depth in [5,4,2,1]:
    for suffix in ['train','valid','test']:
        orig_folder = f'/home/msun415/SynTreeNet/data/gnn_featurized_rxn_target_down_interm_postorder_max_depth=6_{suffix}'
        p = Path(orig_folder)
        for depth in range(max_depth, 0, -1):
            for ind in indices[depth]:
                files = p.rglob(f'{ind}_*')                
                for file in files:
                    dest_folder = f'/home/msun415/SynTreeNet/data/gnn_featurized_rxn_target_down_interm_postorder_max_depth={max_depth}_{suffix}'
                    os.makedirs(dest_folder, exist_ok=True)
                    dest_path = os.path.join(dest_folder, file.name)
                    shutil.copyfile(file, dest_path)
